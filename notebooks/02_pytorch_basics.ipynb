# %% [markdown]
# # Chapitre 2 — PyTorch de base
#
# Tenseurs, autograd, et un petit réseau de neurones de **vision**.
#
# Ce chapitre **peut tourner sans GPU puissant** (CPU OK).
#
# > À porter depuis `breast_cancer/docs/exemple_basics/intro_pytorch.qmd`.

# %%
import torch, torchvision
print('torch', torch.__version__, '| torchvision', torchvision.__version__)
print('CUDA dispo :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU :', torch.cuda.get_device_name(0))
