# %% [markdown]
# # Chapitre 6 — Risques garantis (selective classification)
#
# Les **risques garantis** du papier *Beyond Accuracy: Controlling Broad Error
# Types in Selective Classification* (Jemelen et al., AISTATS 2026) et **comment
# appliquer ces fonctions** : bornes distribution-free, abstention, contrôle
# FNR/FPR.
#
# Peut tourner sans GPU puissant (CPU OK).
#
# Le code est cloné automatiquement dans `~/selective-classification`.
#
# > À porter depuis `breast_cancer/docs/script_notebook/abstention.qmd`,
# > `abstention_algo2.qmd`, et les notebooks `risques_theoriques_FNR_FPR.ipynb` /
# > `comprendre_SE_FNR_prevalence.ipynb`.

# %%
import os, sys
sys.path.insert(0, os.path.expanduser('~/selective-classification'))
from python_scripts.math_utils import B_star
from python_scripts.sgp_utils import sgp_dicho, sgp_greedy_search, DELTA
print('selective-classification importé. DELTA par défaut =', DELTA)
# B_star = borne haute Clopper-Pearson (Proposition A1)
print('exemple B_star(delta=0.005, e=0, n=100) =', B_star(0.005, 0, 100))
